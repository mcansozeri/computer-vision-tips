# %% [markdown]
# **Apply Canny Detector To An Image**

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('mcs.png')
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_blur = cv2.GaussianBlur(img_gray, (3,3), 0)
# Canny Edge Detection
edges = cv2.Canny(image=img_blur, threshold1=50, threshold2=100) # Canny Edge Detection
# Display Canny Edge Detection Image
cv2_imshow(img)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=RGB size=381x386 at 0x7F7811BD9110>
# <PIL.Image.Image image mode=L size=381x386 at 0x7F7811BD92D0>

# %%
#More information you can check the link out: https://learnopencv.com/edge-detection-using-opencv/
